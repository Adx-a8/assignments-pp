# %%
D={1:"aman",2:"patil",3:"lisha"}
T=("aman","patil","lisha")
L=["aman","patil",'lisha']
#Add
D[4]="kunal"
TL=list(T)
TL.append("kunal")
T=tuple(TL)
L.append("kunal")
#Delete
del D[3]
temp_list = list(T)
temp_list.remove("lisha")
T = tuple(temp_list)
L.remove("lisha")
#Update
D[1]="julli"
T=T[:0]+("julli",)+T[1:]
L[0]="julli"

print(D,T,L)
# Out:
# {1: 'julli', 2: 'patil', 4: 'kunal'} ('julli', 'patil', 'kunal') ['julli', 'patil', 'kunal']
